# %%
import matplotlib.pyplot as plt

# %%
x=[43,45,21,26,67]
y=[2016,2017,2018,2019,2020]

# %%
plt.figure(figsize=(5,3))
plt.title('sales report')
plt.xlabel('year')
plt.ylabel('sale value')
plt.bar(y,x)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(3,3))
plt.plot(y,x,marker='o')

# %%
import numpy as np

# %%
x=np.random.randint(10,100,100)

# %%
x
# Out:
# array([32, 22, 35, 14, 60, 15, 37, 43, 89, 90, 68, 74, 91, 21, 37, 87, 10,
#        89, 18, 87, 84, 76, 65, 82, 77, 40, 22, 53, 70, 47, 64, 31, 74, 58,
#        44, 79, 86, 56, 55, 81, 71, 46, 47, 24, 62, 25, 16, 66, 53, 35, 69,
#        88, 86, 38, 93, 89, 25, 42, 33, 88, 87, 93, 50, 39, 83, 55, 77, 53,
#        31, 29, 81, 27, 40, 75, 54, 61, 76, 38, 54, 30, 27, 78, 88, 31, 16,
#        54, 88, 77, 30, 62, 24, 91, 88, 19, 96, 40, 93, 25, 31, 91])

# %%
plt.hist(x)
# Out:
# (array([ 6., 11., 11., 11.,  4., 12.,  8., 10., 11., 16.]),
#  array([10. , 18.6, 27.2, 35.8, 44.4, 53. , 61.6, 70.2, 78.8, 87.4, 96. ]),
#  <BarContainer object of 10 artists>)

# %%
y=np.arange(1,101,1)

# %%
plt.plot(y,x,marker='o')

# %%
sales=[20,35,26,34]
year=[16,17,18,19]

# %%
plt.pie(sales,labels=year,explode=[0.2,0,0,0],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x265eeb604d0>,
# ...
#  [Text(1.1107452190364082, 0.6754591463499193, '16'),
#   Text(-0.5060715216253988, 0.976673750543012, '17'),
#   Text(-0.9238991320490408, -0.5970011673347291, '18'),
#   Text(0.6586585531941819, -0.8810044893779755, '19')],
#  [Text(0.6835355194070204, 0.41566716698456574, '17.4%'),
#   Text(-0.27603901179567203, 0.5327311366598246, '30.4%'),
#   Text(-0.5039449811176586, -0.32563700036439763, '22.6%'),
#   Text(0.359268301742281, -0.48054790329707747, '29.6%')])

# %%
sales=[10,18,26,35,28]
profit=[6,8,21,29,22]
year=[16,17,18,19,20]

# %%
plt.plot(sales,year)
plt.plot(profit,year)

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\DELL\\Downloads\\archive (13)\\headbrain.csv")

# %%
x=np.array(df['Head Size(cm^3)'])
y=np.array(df['Brain Weight(grams)'])

# %%
y
# Out:
# 0      1530
# 1      1297
# 2      1335
# 3      1282
# 4      1590
#        ...
# 232    1110
# 233    1215
# 234    1104
# 235    1170
# 236    1120
# Name: Brain Weight(grams), Length: 237, dtype: int64

# %%
plt.scatter(x,y)

# %%
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
maledata=df[df['Gender']==1]
femaledata=df[df['Gender']==2]

# %%
plt.bar(['male','female'],[len(maledata),len(femaledata)])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(['male','female'],[len(maledata),len(femaledata)])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie([len(maledata),len(femaledata)],labels=['male','female'],autopct='%0.1f')
# Out:
# ([<matplotlib.patches.Wedge at 0x265f1e9c5f0>,
# ...
#  [Text(-0.22442226674499363, 1.0768633368208982, 'male'),
#   Text(0.22442226674499322, -1.0768633368208982, 'female')],
#  [Text(-0.12241214549726923, 0.587380001902308, '56.5'),
#   Text(0.12241214549726902, -0.5873800019023081, '43.5')])
